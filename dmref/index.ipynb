# %% [raw]
# ---
# # title: NSF DMREF
# # subtitle: A National Science Foundation-funded collaboration between
# page-layout: custom
# ---

# %% [markdown]
# ```{css}
# /* Custom two-column styles */
# .guidelines-container {
#   display: flex;
#   gap: 2rem;
#   margin: 2rem 0;
#   flex-wrap: wrap;
# }
#
# .guidelines-col {
#   flex: 1;
#   min-width: 300px;
#   padding: 1.5rem;
#   border-radius: 8px;
#   box-shadow: 0 4px 6px rgba(0,0,0,0.1);
# }
#
# .welcome-col {
#   background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#   color: white;
# }
#
# .rules-col {
#   background: #f8f9fa;
#   border: 1px solid #dee2e6;
# }
#
# @media (max-width: 768px) {
#   .guidelines-container {
#     flex-direction: column;
#   }
# }
#
# /* Discord widget responsive */
# .discord-widget {
#   margin-top: 2rem;
#   text-align: center;
# }
# ```
#
#
#
# ::::{.cmm-background style="display: flex; justify-content: center; align-items: center; min-height: 75vh;"}
# ::: {.content-container}
# ::: {.welcome }
#
# ::: {.g-col-10 .g-col-lg-10 .welcome-text .sand-background style="padding: 2px; text-align: left;"}
#
# # Welcome to Saleno Center Discord! 🎮
#
# 🌟 Introduction
#
# Hey, fellow flourishers! 🎉
#
# Join bi-weekly student meetings for meaningful games sparking growth, empathy, & joy!
#
# Explore Site
#
# Purpose
# Games on life's depths: resilience, connections, creativity.
#
# Core Values
#
# Flourishing
# Respect
# Inclusivity
# Mindfulness
# Our Mission
# Foster flourishing through thoughtful gaming (Saleno-inspired).
#
# Values
# Curiosity • Collaboration • Integrity
# :::
#
# :::{.guidelines-col .rules-col}
#
# 📜 Community Guidelines
# 👥 Conduct
# Do: Kind, insightful, on-topic!
# Don’t: Spam/disrupt/mock.
# Prohibited: Harassment, hate, doxxing, violence.
# Discussions: Flourishing focus; respectful dissent.
#
# 📱 Content
# Acceptable: Clips, reflections, Saleno links.
# Restrictions: No NSFW/gore/spoilers/cheats.
# IP: Credit; no piracy.
#
# 🔒 Privacy/Safety
# No personal info. Report: #report/@Mod.
#
# ♿ Access/Inclusivity
# Clear text/alts; diverse voices!
#
# ⚖️ Conflicts
# DM. 2. #mod-help. 3. Mediate.
# 🔨 Enforcement
# Report (24h): Warn → Mute/Ban. Appeals: DM.
# Joining = Agree! #announcements.
#
# 📞 Contact
# @SalenoAdmin / #general
#
# :::
#
# :::
#
# <!-- Discord Widget (Replace YOUR_SERVER_ID) -->
# <div class="discord-widget">
#   <h3>👋 Jump In Live!</h3>
#   <iframe
#     src="https://discord.com/widget?id=1275852704236703886/1275852704236703888&theme=dark"
#     width="350"
#     height="500"
#     allowtransparency="true"
#     frameborder="0"
#     sandbox="allow-popups allow-popups-to-escape-sandbox allow-same-origin allow-scripts">
#   </iframe>
#   <p><a href="https://discord.gg/QJgyGstK" class="btn btn-primary">Instant Invite</a></p>
# </div>
# :::
#
# :::
